# %%
# !pip install kaggle
# !kaggle competitions download -c titanic

from zipfile import ZipFile
import os
for i in os.listdir('C:/Users/mehmu/Desktop/PyProjects/Projects/Unlocked/KaggleComp/Titanic'):
    if '.zip' in i:
        print(i)
        with ZipFile(i, 'r') as zipObj:
            zipObj.extractall()
        os.remove(i)

# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df_num=df[['Age','SibSp','Parch','Fare']]
df_cat=df[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]

# %%
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
df_num.corr()
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.308247 -0.189119  0.096067
# SibSp -0.308247  1.000000  0.414838  0.159651
# Parch -0.189119  0.414838  1.000000  0.216225
# Fare   0.096067  0.159651  0.216225  1.000000

# %%
sbn.heatmap(df_num.corr())
# Out:
# <AxesSubplot:>

# %%
pd.pivot_table(df,index='Survived',values=['Age','SibSp','Parch','Fare'])
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.626179  22.117887  0.329690  0.553734
# 1         28.343690  48.395408  0.464912  0.473684

# %%
for i in df_cat.columns:
    sbn.barplot(df_cat[i].value_counts().index,df_cat[i].value_counts()).set_title(i)
    plt.show()
# Out:
# c:\Users\mehmu\Desktop\PyProjects\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\mehmu\Desktop\PyProjects\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\mehmu\Desktop\PyProjects\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\mehmu\Desktop\PyProjects\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\mehmu\Desktop\PyProjects\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\mehmu\Desktop\PyProjects\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(pd.pivot_table(df,index='Survived',columns='Pclass',values='Ticket',aggfunc='count'))
print('***********************************')
print(pd.pivot_table(df,index='Survived',columns='Sex',values='Ticket',aggfunc='count'))
print('***********************************')
print(pd.pivot_table(df,index='Survived',columns='Embarked',values='Ticket',aggfunc='count'))
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
# ***********************************
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109
# ***********************************
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
df['Relatives'] = df['SibSp'] + df['Parch']
df.loc[df['Relatives'] > 0, 'Alone'] = 1
df.loc[df['Relatives'] == 0, 'Alone'] = 0

# %%
df_test['Relatives'] = df_test['SibSp'] + df_test['Parch']
df_test.loc[df_test['Relatives'] > 0, 'Alone'] = 1
df_test.loc[df_test['Relatives'] == 0, 'Alone'] = 0

# %%
df["Title"] = df["Name"].str.extract('([A-Za-z]+)\.')

df["Title"].value_counts()

df_test["Title"] = df_test["Name"].str.extract('([A-Za-z]+)\.')

df_test["Title"].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dr          1
# Dona        1
# Name: Title, dtype: int64

# %%
def convert_title(title):
    if title in ["Ms", "Mile", "Miss"]:
        return "Miss"
    elif title in ["Mme", "Mrs"]:
        return "Mrs"
    elif title == "Mr":
        return "Mr"
    elif title == "Master":
        return "Master"
    else:
        return "Other"
        
df["Title"] = df["Title"].map(convert_title)
df_test["Title"] = df_test["Title"].map(convert_title)
df["Title"].value_counts()
# Out:
# Mr        517
# Miss      183
# Mrs       126
# Master     40
# Other      25
# Name: Title, dtype: int64

# %%
df.drop("Name", axis=1, inplace=True)
df_test.drop("Name", axis=1, inplace=True)

# %%
df.groupby('Title')['Age'].mean()
# Out:
# Title
# Master     4.574167
# Miss      21.816327
# Mr        32.368090
# Mrs       35.788991
# Other     43.750000
# Name: Age, dtype: float64

# %%
for i in [df,df_test]:    
    i.loc[(i["Age"].isnull()) & (i["Title"]=='Master'), 'Age'] = 5
    i.loc[(i["Age"].isnull()) & (i["Title"]=='Miss'), 'Age'] = 22
    i.loc[(i["Age"].isnull()) & (i["Title"]=='Mr'), 'Age'] = 32
    i.loc[(i["Age"].isnull()) & (i["Title"]=='Mrs'), 'Age'] = 36
    i.loc[(i["Age"].isnull()) & (i["Title"]=='Other'), 'Age'] = 44

# %%
df_test.Fare.fillna(df.groupby("Pclass").mean()["Fare"][3], inplace=True)

# %%
for i in [df,df_test]:
    i.drop('PassengerId',axis=1,inplace=True)
    i.drop('Ticket',axis=1,inplace=True)
    i.drop('Cabin',axis=1,inplace=True)

# %%
df_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked  Relatives  Alone  \
# 0         3    male  34.5      0      0    7.8292        Q          0    0.0
# 1         3  female  47.0      1      0    7.0000        S          1    1.0
# 2         2    male  62.0      0      0    9.6875        Q          0    0.0
# 3         3    male  27.0      0      0    8.6625        S          0    0.0
# 4         3  female  22.0      1      1   12.2875        S          2    1.0
# ..      ...     ...   ...    ...    ...       ...      ...        ...    ...
# 413       3    male  32.0      0      0    8.0500        S          0    0.0
# 414       1  female  39.0      0      0  108.9000        C          0    0.0
# 415       3    male  38.5      0      0    7.2500        S          0    0.0
# 416       3    male  32.0      0      0    8.0500        S          0    0.0
# 417       3    male   5.0      1      1   22.3583        C          2    1.0
#
#       Title
# 0        Mr
# 1       Mrs
# 2        Mr
# 3        Mr
# 4       Mrs
# ..      ...
# 413      Mr
# 414   Other
# 415      Mr
# 416      Mr
# 417  Master
#
# [418 rows x 10 columns]

# %%
df = pd.get_dummies(df, prefix=["Sex", "Embarked", "Title"])
df_test = pd.get_dummies(df_test, prefix=["Sex", "Embarked", "Title"])

# %%
# !pip install xgboost lightgbm
# Out:
# Requirement already satisfied: xgboost in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (1.6.1)
# Requirement already satisfied: lightgbm in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (3.3.2)
# Requirement already satisfied: numpy in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (from xgboost) (1.23.0)
# Requirement already satisfied: scipy in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (from xgboost) (1.8.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (from lightgbm) (1.1.1)
# Requirement already satisfied: wheel in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\mehmu\desktop\pyprojects\env\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)

# %%
df_test
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Relatives  Alone  Sex_female  \
# 0         3  34.5      0      0    7.8292          0    0.0           0
# 1         3  47.0      1      0    7.0000          1    1.0           1
# 2         2  62.0      0      0    9.6875          0    0.0           0
# 3         3  27.0      0      0    8.6625          0    0.0           0
# 4         3  22.0      1      1   12.2875          2    1.0           1
# ..      ...   ...    ...    ...       ...        ...    ...         ...
# 413       3  32.0      0      0    8.0500          0    0.0           0
# 414       1  39.0      0      0  108.9000          0    0.0           1
# 415       3  38.5      0      0    7.2500          0    0.0           0
# 416       3  32.0      0      0    8.0500          0    0.0           0
# 417       3   5.0      1      1   22.3583          2    1.0           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S  Title_Master  Title_Miss  \
# 0           1           0           1           0             0           0
# 1           0           0           0           1             0           0
# 2           1           0           1           0             0           0
# 3           1           0           0           1             0           0
# 4           0           0           0           1             0           0
# ..        ...         ...         ...         ...           ...         ...
# 413         1           0           0           1             0           0
# 414         0           1           0           0             0           0
# 415         1           0           0           1             0           0
# 416         1           0           0           1             0           0
# 417         1           1           0           0             1           0
#
#      Title_Mr  Title_Mrs  Title_Other
# 0           1          0            0
# 1           0          1            0
# 2           1          0            0
# 3           1          0            0
# 4           0          1            0
# ..        ...        ...          ...
# 413         1          0            0
# 414         0          0            1
# 415         1          0            0
# 416         1          0            0
# 417         0          0            0
#
# [418 rows x 17 columns]

# %%
df_test.drop(['Sex_33','Embarked_33','Title_33'],axis=1,inplace=True)

df.drop('Sex_female',axis=1,inplace=True)
df_test.drop('Sex_female',axis=1,inplace=True)

# %%
X_train = df.drop("Survived", axis=1)
y_train = df.Survived

X_test = df_test.copy()

# %%
X_test
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Relatives  Alone  Sex_female  \
# 0         3  34.5      0      0    7.8292          0    0.0           0
# 1         3  47.0      1      0    7.0000          1    1.0           1
# 2         2  62.0      0      0    9.6875          0    0.0           0
# 3         3  27.0      0      0    8.6625          0    0.0           0
# 4         3  22.0      1      1   12.2875          2    1.0           1
# ..      ...   ...    ...    ...       ...        ...    ...         ...
# 413       3  32.0      0      0    8.0500          0    0.0           0
# 414       1  39.0      0      0  108.9000          0    0.0           1
# 415       3  38.5      0      0    7.2500          0    0.0           0
# 416       3  32.0      0      0    8.0500          0    0.0           0
# 417       3   5.0      1      1   22.3583          2    1.0           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S  Title_Master  Title_Miss  \
# 0           1           0           1           0             0           0
# 1           0           0           0           1             0           0
# 2           1           0           1           0             0           0
# 3           1           0           0           1             0           0
# 4           0           0           0           1             0           0
# ..        ...         ...         ...         ...           ...         ...
# 413         1           0           0           1             0           0
# 414         0           1           0           0             0           0
# 415         1           0           0           1             0           0
# 416         1           0           0           1             0           0
# 417         1           1           0           0             1           0
#
#      Title_Mr  Title_Mrs  Title_Other
# 0           1          0            0
# 1           0          1            0
# 2           1          0            0
# 3           1          0            0
# 4           0          1            0
# ..        ...        ...          ...
# 413         1          0            0
# 414         0          0            1
# 415         1          0            0
# 416         1          0            0
# 417         0          0            0
#
# [418 rows x 17 columns]

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Relatives  Alone  Sex_female  \
# 0         3  22.0      1      0   7.2500          1    1.0           0
# 1         1  38.0      1      0  71.2833          1    1.0           1
# 2         3  26.0      0      0   7.9250          0    0.0           1
# 3         1  35.0      1      0  53.1000          1    1.0           1
# 4         3  35.0      0      0   8.0500          0    0.0           0
# ..      ...   ...    ...    ...      ...        ...    ...         ...
# 886       2  27.0      0      0  13.0000          0    0.0           0
# 887       1  19.0      0      0  30.0000          0    0.0           1
# 888       3  22.0      1      2  23.4500          3    1.0           1
# 889       1  26.0      0      0  30.0000          0    0.0           0
# 890       3  32.0      0      0   7.7500          0    0.0           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S  Title_Master  Title_Miss  \
# 0           1           0           0           1             0           0
# 1           0           1           0           0             0           0
# 2           0           0           0           1             0           1
# 3           0           0           0           1             0           0
# 4           1           0           0           1             0           0
# ..        ...         ...         ...         ...           ...         ...
# 886         1           0           0           1             0           0
# 887         0           0           0           1             0           1
# 888         0           0           0           1             0           1
# 889         1           1           0           0             0           0
# 890         1           0           1           0             0           0
#
#      Title_Mr  Title_Mrs  Title_Other
# 0           1          0            0
# 1           0          1            0
# 2           0          0            0
# 3           0          1            0
# 4           1          0            0
# ..        ...        ...          ...
# 886         0          0            1
# 887         0          0            0
# 888         0          0            0
# 889         1          0            0
# 890         1          0            0
#
# [891 rows x 17 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, accuracy_score, f1_score, confusion_matrix


classifiers = {
    "KNN": KNeighborsClassifier(), 
    "LR": LogisticRegression(max_iter=1000), 
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    "SVM": SVC(),
    "MLP": MLPClassifier(max_iter=1000),
    "XGB": XGBClassifier(),
    "LGBM": LGBMClassifier()
}

results = pd.DataFrame(columns=["Classifier", "Avg_Accuracy", "Avg_F1_Score"])
for name, clf in classifiers.items():
    model = clf
    cv_results = cross_validate(
        model, X_train_scaled, y_train, cv=10,
        scoring=(['accuracy', 'f1'])
    )

    results = results.append({
        "Classifier": name,
        "Avg_Accuracy": cv_results['test_accuracy'].mean(),
        "Avg_F1_Score": cv_results['test_f1'].mean()
    }, ignore_index=True)
    
results["Avg_Overall"] = (results["Avg_Accuracy"] + results["Avg_F1_Score"]) / 2
results = results.sort_values("Avg_Overall", ascending=False)
results
# Out:
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# C:\Users\mehmu\AppData\Local\Temp\ipykernel_40024\1537685924.py:32: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
#   Classifier  Avg_Accuracy  Avg_F1_Score  Avg_Overall
# 4        SVM      0.835019      0.769358     0.802188
# 1         LR      0.831660      0.771142     0.801401
# 6        XGB      0.821610      0.761686     0.791648
# 5        MLP      0.827166      0.755416     0.791291
# 7       LGBM      0.820462      0.757552     0.789007
# 0        KNN      0.817116      0.742895     0.780006
# 3         RF      0.808152      0.742380     0.775266
# 2         DT      0.787915      0.722495     0.755205

# %%
plt.figure(figsize=(12, 6))
sbn.barplot(data=results, x="Avg_Overall", y="Classifier")
plt.title("Average Overall CV Score")
plt.show()

# %%
svm = SVC()
params = {
    "tol": (0.1, 0.01, 0.001, 0.0001,0.00001),
    "C": (10.0, 1.0, 0.1, 0.01)
}
clf = GridSearchCV(svm, params, cv=10)
clf.fit(X_train_scaled, y_train)
print("Best hyperparameter:", clf.best_params_)
# Out:
# Best hyperparameter: {'C': 1.0, 'tol': 0.1}

# %%
y_pred = clf.predict(X_train_scaled)
print(f"Train Accuracy: {accuracy_score(y_train, y_pred)}")
print(f"Train F1-Score: {f1_score(y_train, y_pred)}")
sbn.heatmap(confusion_matrix(y_train, y_pred), fmt='.3g', annot=True, cmap='summer_r')
plt.show()
# Out:
# Train Accuracy: 0.8428731762065096
# Train F1-Score: 0.7852760736196319

# %%
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88       549
#            1       0.83      0.75      0.79       342
#
#     accuracy                           0.84       891
#    macro avg       0.84      0.83      0.83       891
# weighted avg       0.84      0.84      0.84       891

# %%
y_pred = clf.predict(X_test_scaled)

submission = pd.read_csv("gender_submission.csv")
submission["Survived"] = y_pred
submission.to_csv('submission.csv', index=False)

# %%
# !kaggle competitions submit -c titanic -f submission.csv -m ""
# Out:
# Successfully submitted to Titanic - Machine Learning from Disaster
#   0%|          | 0.00/3.18k [00:00<?, ?B/s]
# 100%|██████████| 3.18k/3.18k [00:00<00:00, 30.5kB/s]
# 100%|██████████| 3.18k/3.18k [00:02<00:00, 1.57kB/s]
